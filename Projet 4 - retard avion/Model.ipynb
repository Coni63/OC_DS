# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error#, mean_squared_log_error

# %matplotlib inline

# %%
df = pd.read_csv("dataset/merged/prod_dataset.csv")
df.dropna(axis=1, how="all", inplace=True)

# %%
# for col in df:
#     if df[col].dtype in ["int64", "float64"]:
#         df[col] = df[col].astype("int32")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5256250 entries, 0 to 5256249
# Data columns (total 8 columns):
# MONTH                int64
# DAY_OF_MONTH         int64
# DAY_OF_WEEK          int64
# UNIQUE_CARRIER       object
# ORIGIN_AIRPORT_ID    float64
# DEST_AIRPORT_ID      int64
# DEP_DELAY            int64
# SHIFT                int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 320.8+ MB

# %%
df
# Out:
#          MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER  ORIGIN_AIRPORT_ID  \
# 0            1             6            3             AA               1.00
# 1            1             7            4             AA               1.00
# 2            1             8            5             AA               1.00
# 3            1             9            6             AA               1.00
# 4            1            11            1             AA               1.00
# 5            1            12            2             AA               1.00
# 6            1            13            3             AA               1.00
# 7            1            14            4             AA               1.00
# 8            1            15            5             AA               1.00
# 9            1            16            6             AA               1.00
# 10           1            17            7             AA               1.00
# 11           1            18            1             AA               1.00
# 12           1            19            2             AA               1.00
# 13           1            20            3             AA               1.00
# 14           1            21            4             AA               1.00
# 15           1            22            5             AA               1.00
# 16           1            23            6             AA               1.00
# 17           1            24            7             AA               1.00
# 18           1            25            1             AA               1.00
# 19           1            26            2             AA               1.00
# 20           1            27            3             AA               1.00
# 21           1            28            4             AA               1.00
# 22           1            29            5             AA               1.00
# 23           1            30            6             AA               1.00
# 24           1            31            7             AA               1.00
# 25           1             1            5             AA               1.00
# 26           1             2            6             AA               1.00
# 27           1             3            7             AA               1.00
# 28           1             4            1             AA               1.00
# 29           1             5            2             AA               1.00
# ...        ...           ...          ...            ...                ...
# 5256220     12            31            6             WN               0.75
# 5256221     12            31            6             WN               0.75
# 5256222     12            31            6             WN               0.75
# 5256223     12            31            6             WN               0.75
# 5256224     12            31            6             WN               0.75
# 5256225     12            31            6             WN               0.75
# 5256226     12            31            6             WN               0.75
# 5256227     12            31            6             WN               0.75
# 5256228     12            31            6             WN               0.75
# 5256229     12            31            6             WN               0.75
# 5256230     12            31            6             WN               0.75
# 5256231     12            31            6             WN               0.50
# 5256232     12            31            6             WN               0.50
# 5256233     12            31            6             WN               0.50
# 5256234     12            31            6             WN               0.50
# 5256235     12            31            6             WN               0.50
# 5256236     12            31            6             WN               0.50
# 5256237     12            31            6             WN               0.50
# 5256238     12            31            6             WN               0.50
# 5256239     12            31            6             WN               0.50
# 5256240     12            31            6             WN               0.75
# 5256241     12            31            6             WN               0.75
# 5256242     12            31            6             WN               0.75
# 5256243     12            31            6             WN               0.75
# 5256244     12            31            6             WN               0.75
# 5256245     12            31            6             WN               0.75
# 5256246     12            31            6             WN               0.75
# 5256247     12            31            6             WN               0.75
# 5256248     12            31            6             WN               0.75
# 5256249     12            31            6             WN               0.75
#
#          DEST_AIRPORT_ID  DEP_DELAY  SHIFT
# 0                  11433         -3    645
# 1                  11433         -4    645
# 2                  11433         -5    645
# 3                  11433          2    645
# 4                  11433          7    645
# 5                  11433         -1    645
# 6                  11433         -5    645
# 7                  11433         -2    645
# 8                  11433         -4    645
# 9                  11433         -4    645
# 10                 11433         -7    645
# 11                 11433         -5    645
# 12                 11433         14    645
# 13                 11433         -6    645
# 14                 11433         34    645
# 15                 11433         -5    645
# 16                 11433         -7    645
# 17                 11433         10    645
# 18                 11433         -1    645
# 19                 11433         -4    645
# 20                 11433          1    645
# 21                 11433          0    645
# 22                 11433         -2    645
# 23                 11433         64    645
# 24                 11433          0    645
# 25                 11298         26    898
# 26                 11298         -4    898
# 27                 11298          2    898
# 28                 11298         -4    898
# 29                 11298         -4    908
# ...                  ...        ...    ...
# 5256220            14122         -4    635
# 5256221            14122         49    830
# 5256222            14307          6    855
# 5256223            14307         -2    520
# 5256224            14492         -6    785
# 5256225            14576          5    820
# 5256226            14683          0    935
# 5256227            14730         -5   1020
# 5256228            14843          5    905
# 5256229            14843         -3    495
# 5256230            15016         -7    795
# 5256231            11259         -2   1025
# 5256232            11259         -1    690
# 5256233            11259         -3    395
# 5256234            11292          5    405
# 5256235            12191         -3    450
# 5256236            12191         -6    955
# 5256237            12889         -1    615
# 5256238            14107         -3    455
# 5256239            15016         -4    570
# 5256240            11292         -2    415
# 5256241            11292         -5    975
# 5256242            12889          7    790
# 5256243            12889          2    670
# 5256244            12889         -2    930
# 5256245            12892         -8    460
# 5256246            12892          5    785
# 5256247            13232         -6    410
# 5256248            14679         -1    725
# 5256249            14679         -2    465
#
# [5256250 rows x 8 columns]

# %%
#df.drop(["CRS_ARR_TIME", "DISTANCE", "ARR_DELAY"], axis=1, inplace = True)
#df.drop(["CRS_DEP_TIME"], axis=1, inplace = True)

# %%
# df = pd.concat([df, pd.get_dummies(df["UNIQUE_CARRIER"])], axis=1)
# df = pd.concat([df, pd.get_dummies(df["MONTH"], prefix="MONTH_")], axis=1)
# df = pd.concat([df, pd.get_dummies(df["DAY_OF_MONTH"], prefix="DAYM_")], axis=1)
# df = pd.concat([df, pd.get_dummies(df["DAY_OF_WEEK"], prefix="DAY_")], axis=1)
# df = pd.concat([df, pd.get_dummies(df["NUM_WEEK"], prefix="WEEK_")], axis=1)

# df = pd.concat([df, pd.get_dummies(df["ORIGIN_AIRPORT_ID"])], axis=1)
# df = pd.concat([df, pd.get_dummies(df["DEST_AIRPORT_ID"])], axis=1)
# df = pd.concat([df, pd.get_dummies(df["CRS_DEP_TIME"])], axis=1)
# df = pd.concat([df, pd.get_dummies(df["CRS_ARR_TIME"])], axis=1)

# %%
carrier_list = df["UNIQUE_CARRIER"].unique()  # required for prod

# df.drop(["UNIQUE_CARRIER"], axis=1, inplace = True)
# df.drop("MONTH", axis=1, inplace = True)
# df.drop("DAY_OF_MONTH", axis=1, inplace = True)
# df.drop("DAY_OF_WEEK", axis=1, inplace = True)
# df.drop("NUM_WEEK", axis=1, inplace = True)

# df.drop("ORIGIN_AIRPORT_ID", axis=1, inplace = True)
# df.drop("DEST_AIRPORT_ID", axis=1, inplace = True)
# df.drop("CRS_DEP_TIME", axis=1, inplace = True)
# df.drop("UNIQUE_CARRIER", axis=1, inplace = True)
# df.drop("CRS_ARR_TIME", axis=1, inplace = True)

# %%
week_format = False

if week_format:
    df = pd.concat([df, pd.get_dummies(df["UNIQUE_CARRIER"])], axis=1)
    df = pd.concat([df, pd.get_dummies(df["DAY_OF_WEEK"], prefix="DAY_")], axis=1)
    df = pd.concat([df, pd.get_dummies(df["NUM_WEEK"], prefix="WEEK_")], axis=1)

    df.drop(["UNIQUE_CARRIER"], axis=1, inplace = True)
    df.drop("DAY_OF_WEEK", axis=1, inplace = True)
    df.drop("NUM_WEEK", axis=1, inplace = True)
else:
    df = pd.concat([df, pd.get_dummies(df["UNIQUE_CARRIER"])], axis=1)
    df = pd.concat([df, pd.get_dummies(df["MONTH"], prefix="MONTH_")], axis=1)
    df = pd.concat([df, pd.get_dummies(df["DAY_OF_MONTH"], prefix="DAYM_")], axis=1)
    df = pd.concat([df, pd.get_dummies(df["DAY_OF_WEEK"], prefix="DAY_")], axis=1)

    df.drop(["UNIQUE_CARRIER"], axis=1, inplace=True)
    df.drop("MONTH", axis=1, inplace=True)
    df.drop("DAY_OF_MONTH", axis=1, inplace=True)
    df.drop("DAY_OF_WEEK", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5256250 entries, 0 to 5256249
# Data columns (total 66 columns):
# ORIGIN_AIRPORT_ID    int32
# DEST_AIRPORT_ID      int32
# DEP_DELAY            int32
# SHIFT                int32
# AA                   uint8
# AS                   uint8
# B6                   uint8
# DL                   uint8
# EV                   uint8
# F9                   uint8
# HA                   uint8
# NK                   uint8
# OO                   uint8
# UA                   uint8
# VX                   uint8
# WN                   uint8
# MONTH__1             uint8
# MONTH__2             uint8
# MONTH__3             uint8
# MONTH__4             uint8
# MONTH__5             uint8
# MONTH__6             uint8
# MONTH__7             uint8
# MONTH__8             uint8
# MONTH__9             uint8
# MONTH__10            uint8
# MONTH__11            uint8
# MONTH__12            uint8
# DAYM__1              uint8
# DAYM__2              uint8
# DAYM__3              uint8
# DAYM__4              uint8
# DAYM__5              uint8
# DAYM__6              uint8
# DAYM__7              uint8
# DAYM__8              uint8
# DAYM__9              uint8
# DAYM__10             uint8
# DAYM__11             uint8
# DAYM__12             uint8
# DAYM__13             uint8
# DAYM__14             uint8
# DAYM__15             uint8
# DAYM__16             uint8
# DAYM__17             uint8
# DAYM__18             uint8
# DAYM__19             uint8
# DAYM__20             uint8
# DAYM__21             uint8
# DAYM__22             uint8
# DAYM__23             uint8
# DAYM__24             uint8
# DAYM__25             uint8
# DAYM__26             uint8
# DAYM__27             uint8
# DAYM__28             uint8
# DAYM__29             uint8
# DAYM__30             uint8
# DAYM__31             uint8
# DAY__1               uint8
# DAY__2               uint8
# DAY__3               uint8
# DAY__4               uint8
# DAY__5               uint8
# DAY__6               uint8
# DAY__7               uint8
# dtypes: int32(4), uint8(62)
# memory usage: 391.0 MB

# %%
df.describe()
# Out:
#        ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID     DEP_DELAY         SHIFT  \
# count       5.256250e+06     5.256250e+06  5.256250e+06  5.256250e+06
# mean        1.268139e+04     1.268093e+04  4.772070e+00  7.888426e+02
# std         1.536334e+03     1.536152e+03  2.889505e+01  2.945613e+02
# min         1.013500e+04     1.013500e+04 -2.040000e+02  0.000000e+00
# 25%         1.129200e+04     1.129200e+04 -5.000000e+00  5.350000e+02
# 50%         1.288900e+04     1.288900e+04 -2.000000e+00  7.800000e+02
# 75%         1.405700e+04     1.405700e+04  4.000000e+00  1.035000e+03
# max         1.621800e+04     1.621800e+04  2.149000e+03  1.424000e+03
#
#                  AA            AS            B6            DL            EV  \
# count  5.256250e+06  5.256250e+06  5.256250e+06  5.256250e+06  5.256250e+06
# mean   1.599102e-01  3.022440e-02  4.640247e-02  1.701125e-01  8.326221e-02
# std    3.665228e-01  1.712042e-01  2.103552e-01  3.757317e-01  2.762782e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  F9      ...           WEEK__44      WEEK__45      WEEK__46  \
# count  5.256250e+06      ...       5.256250e+06  5.256250e+06  5.256250e+06
# mean   1.618340e-02      ...       1.916956e-02  1.952209e-02  1.986759e-02
# std    1.261804e-01      ...       1.371207e-01  1.383509e-01  1.395452e-01
# min    0.000000e+00      ...       0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00      ...       0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00      ...       0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00      ...       0.000000e+00  0.000000e+00  0.000000e+00
# max    1.000000e+00      ...       1.000000e+00  1.000000e+00  1.000000e+00
#
#            WEEK__47      WEEK__48      WEEK__49      WEEK__50      WEEK__51  \
# count  5.256250e+06  5.256250e+06  5.256250e+06  5.256250e+06  5.256250e+06
# mean   1.859025e-02  1.994844e-02  1.877612e-02  1.841960e-02  1.807772e-02
# std    1.350728e-01  1.398231e-01  1.357335e-01  1.344631e-01  1.332326e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#            WEEK__52      WEEK__53
# count  5.256250e+06  5.256250e+06
# mean   1.879058e-02  5.223115e-03
# std    1.357848e-01  7.208214e-02
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00
#
# [8 rows x 76 columns]

# %% [markdown]
# ## Split data

# %%
y = df["DEP_DELAY"]
X = df.drop("DEP_DELAY", axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5256250 entries, 0 to 5256249
# Data columns (total 76 columns):
# Unnamed: 0           int32
# ORIGIN_AIRPORT_ID    int32
# DEST_AIRPORT_ID      int32
# SHIFT                int32
# AA                   uint8
# AS                   uint8
# B6                   uint8
# DL                   uint8
# EV                   uint8
# F9                   uint8
# HA                   uint8
# NK                   uint8
# OO                   uint8
# UA                   uint8
# VX                   uint8
# WN                   uint8
# DAY__1               uint8
# DAY__2               uint8
# DAY__3               uint8
# DAY__4               uint8
# DAY__5               uint8
# DAY__6               uint8
# DAY__7               uint8
# WEEK__1              uint8
# WEEK__2              uint8
# WEEK__3              uint8
# WEEK__4              uint8
# WEEK__5              uint8
# WEEK__6              uint8
# WEEK__7              uint8
# WEEK__8              uint8
# WEEK__9              uint8
# WEEK__10             uint8
# WEEK__11             uint8
# WEEK__12             uint8
# WEEK__13             uint8
# WEEK__14             uint8
# WEEK__15             uint8
# WEEK__16             uint8
# WEEK__17             uint8
# WEEK__18             uint8
# WEEK__19             uint8
# WEEK__20             uint8
# WEEK__21             uint8
# WEEK__22             uint8
# WEEK__23             uint8
# WEEK__24             uint8
# WEEK__25             uint8
# WEEK__26             uint8
# WEEK__27             uint8
# WEEK__28             uint8
# WEEK__29             uint8
# WEEK__30             uint8
# WEEK__31             uint8
# WEEK__32             uint8
# WEEK__33             uint8
# WEEK__34             uint8
# WEEK__35             uint8
# WEEK__36             uint8
# WEEK__37             uint8
# WEEK__38             uint8
# WEEK__39             uint8
# WEEK__40             uint8
# WEEK__41             uint8
# WEEK__42             uint8
# WEEK__43             uint8
# WEEK__44             uint8
# WEEK__45             uint8
# WEEK__46             uint8
# WEEK__47             uint8
# WEEK__48             uint8
# WEEK__49             uint8
# WEEK__50             uint8
# WEEK__51             uint8
# WEEK__52             uint8
# WEEK__53             uint8
# dtypes: int32(4), uint8(72)
# memory usage: 441.1 MB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scale = scaler.fit_transform(X.values)
# Out:
# C:\Anaconda501\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.2)

# %% [markdown]
# ### La Linear Regression Classique ne passe pas en memoire

# %% [markdown]
# ### Le Batch Gradient Descent ne vas aussi pas être testé car il necessite le calcul du gradient sur tout le dataset
# c'est aussi très gourmand

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import GridSearchCV

# %%
# parameters = {'max_iter':[5, 10, 20, 40], 'penalty':[None, "l1", "l2", "elasticnet"], "alpha":[0.0001, 0.001, 0.01], "l1_ratio": [0.15, 0.5, 0.85] }  # max_iter=20, penalty=None, eta0 = 0.1
# model = SGDRegressor()
# reg = GridSearchCV(model, parameters, cv=3, scoring='neg_mean_absolute_error')
# reg.fit(X_train, y_train)

### Crash sur Notebook à cause de OOM. Test fait sur un script normal dont voici le resultat apres 40 min de calcul (512 model entrainés (4 (max iter)*4 (penalty)*3 (alpha)*3 (l1_ratio)*3 (cv)))

# %% [markdown]
# <img src="Projet 4 - training.png"/>

# %%
# print(reg.best_params_)
# print(reg.best_estimator_)

# %%
# parameters = {'max_iter':[20], 'penalty':["l2"], "alpha":[0.001], "l1_ratio": [0.85] }
# model = SGDRegressor()
# reg = GridSearchCV(model, parameters, cv=3, scoring='neg_mean_absolute_error')
# reg.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', max_iter=None, n_iter=None, penalty='l2',
#        power_t=0.25, random_state=None, shuffle=True, tol=None, verbose=0,
#        warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_iter': [20], 'penalty': ['l2'], 'alpha': [0.001], 'l1_ratio': [0.85]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=0)

# %%
# best_model = reg.best_estimator_

# %%
model = SGDRegressor(max_iter=20)
model.fit(X_train, y_train)
best_model = model

# %%
y_pred = best_model.predict(X_test)

# %%
print(mean_squared_error(y_test, y_pred)**(1/2))
# Out:
# 28.4590328268

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 12.477385331214609

# %%
a = 10
s = 100
pred = best_model.predict(X_test[s:s+a])
for x, y in zip(y_pred, y_test[s:s+a]):
    print(x, " => ", y)
# Out:
# 4.28605594978  =>  -2
# 2.30136070063  =>  -6
# 3.54636199685  =>  0
# 0.218512537764  =>  14
# -2.69249982045  =>  -4
# 2.77619369087  =>  -6
# 7.35112153123  =>  -4
# 6.23377444459  =>  19
# 2.30472363436  =>  18
# 1.09428989852  =>  -7

# %% [markdown]
# ### Boosting
#
# Comme il n'y a pas 50 modèle possible pour tant de données, on peut passer sur du bagging ou du boosting. Dans notre cas, on overfitt pas le modèle car ona un modèle linéaire donc le bagging n'a pas particulièrement d'interet mais le boosting peut aider

# %%
# from sklearn.ensemble import GradientBoostingRegressor

# Gbooster = GradientBoostingRegressor(
#                                     loss="lad",
#                                     n_estimators=20,
#                                     max_depth=3,
#                                     criterion = "mae"
#                                    )

# %%
# Gbooster.fit(X_train, y_train)

# %%
# y_pred = Gbooster.predict(X_test)
# print(mean_squared_error(y_test, y_pred)**(1/2))
# print(mean_absolute_error(y_test, y_pred))

# %%
# a = 10
# s = 100
# pred = Gbooster.predict(X_test[s:s+a])
# for x, y in zip(y_pred, y_test[s:s+a]):
#     print(x, " => ", y)

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
booster = AdaBoostRegressor(
                            base_estimator=best_model,
                            n_estimators=5,
                            loss="linear"
                           )

# %%
booster.fit(X_train, y_train)

# %%
y_pred = booster.predict(X_test)
print(mean_squared_error(y_test, y_pred)**(1/2))
print(mean_absolute_error(y_test, y_pred))

# %%
a = 10
s = 100
pred = booster.predict(X_test[s:s+a])
for x, y in zip(y_pred, y_test[s:s+a]):
    print(x, " => ", y)

# %% [markdown]
# ### Analyse

# %%
# features_name = list(X)
# nb_features = len(list(X))
# reg_name = ['SGDRegressor', 'AdaBoost'] # 'Gradient Boosting'
# nb_reg = len(reg_name)

# df_importance = pd.DataFrame(columns=range(nb_features))

# column_pairs = dict(zip(list(range(nb_features)), features_name))
# index_pairs = dict(zip(list(range(nb_reg)),reg_name))  

# df_importance.loc[0] = best_model.coef_
# df_importance.loc[1] = booster.coef_ #feature_importances_
# #df_importance.loc[2] = Gbooster.feature_importances_

# df_importance2 = df_importance.rename(index=index_pairs, columns=column_pairs)
# df_importance2.T

# plt.figure(figsize = (18, 6))
# sns.heatmap(df_importance2, cmap='Blues')

# %% [markdown]
# ### Bonus - Simple NN

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import numpy
# Out:
# Using TensorFlow backend.

# %%
print(X_train.shape)
print(y_train.shape)

# %%
model = Sequential()
model.add(Dense(150, input_dim=X_train.shape[1], activation='elu'))
model.add(Dense(150, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(150, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error']) => loss 12.61
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

early_stop = EarlyStopping(monitor='loss', min_delta=0, patience=5, verbose=0, mode='auto')

# %%
model.fit(X_train, y_train, epochs=10, batch_size=5000, callbacks = [early_stop])

# https://stackoverflow.com/questions/46999519/keras-model-fit-unboundlocalerror

# %%
model.fit(X_train, y_train, epochs=10, batch_size=5000, callbacks = [early_stop])

# %%
print("{} - {:.2f}".format(model.metrics_names[1], scores[1]))
print("{} - {:.2f}".format(model.metrics_names[2], scores[2]))

# %%
a = 10
s = 100
pred = model.predict(X_test[s:s+a])
for x, y in zip(pred, y_test[s:s+a]):
    print(x[0], " => ", y)

# %% [markdown]
# ### Sauvegarde du model pour Webservice

# %%
from sklearn.externals import joblib

joblib.dump(scaler, 'scaler.pkl') 
joblib.dump(booster, 'model.pkl') 
#clf = joblib.load('filename.pkl')
# Out:
# ['model.pkl']

# %%
airports = pd.read_csv("L_AIRPORT_ID.csv")
companies = pd.read_csv("L_UNIQUE_CARRIERS.csv")

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1633 entries, 0 to 1632
# Data columns (total 2 columns):
# Code           1632 non-null object
# Description    1633 non-null object
# dtypes: object(2)
# memory usage: 25.6+ KB

# %%
first = df["DEST_AIRPORT_ID"].unique()
second = df["ORIGIN_AIRPORT_ID"].unique()
third = list(set(first) | set(second)) 
print(third)
# Out:
# [11267, 10245, 15370, 11278, 15376, 10257, 15380, 11292, 15389, 13342, 13344, 11298, 12323, 10279, 15401, 11308, 12335, 13360, 12339, 15412, 15411, 13367, 12343, 10299, 13377, 11336, 11337, 13388, 10333, 12389, 12391, 12397, 13422, 12402, 14457, 13433, 10372, 15497, 13459, 11413, 14487, 12441, 14489, 14492, 10397, 11423, 12448, 12451, 13476, 10408, 11433, 13485, 13486, 13487, 10423, 13495, 11447, 14520, 14524, 12478, 13502, 10431, 10434, 11471, 14543, 11481, 12511, 10469, 13541, 12519, 11495, 14570, 12523, 14574, 11503, 14576, 15607, 14588, 11525, 15624, 13577, 11537, 11540, 10529, 14633, 14635, 10551, 11577, 10561, 11587, 10577, 14674, 11603, 10581, 14679, 14683, 11612, 14685, 14689, 11618, 11617, 10599, 11624, 14696, 14698, 11630, 14709, 11638, 11637, 14711, 11641, 10620, 11648, 10627, 10631, 14730, 14747, 10666, 11695, 11697, 14771, 10685, 14783, 10693, 11721, 14794, 12758, 10713, 14814, 10721, 15841, 13795, 13796, 10728, 10731, 14828, 10732, 14831, 10739, 14842, 10747, 14843, 11775, 10754, 11778, 13830, 12819, 14869, 15897, 13851, 10779, 10781, 10785, 10792, 14893, 13871, 10800, 13873, 15919, 11823, 14905, 14908, 13891, 10821, 12884, 12888, 12889, 11865, 12891, 12892, 11867, 12896, 10849, 12898, 14952, 13930, 13931, 11884, 13933, 14955, 14960, 12915, 10868, 15991, 10874, 11898, 11905, 14986, 13964, 12945, 13970, 11921, 12951, 12953, 12954, 10918, 15016, 10926, 15024, 11953, 15027, 12982, 14006, 12992, 15041, 11973, 11977, 14025, 14027, 11980, 11982, 11986, 11995, 11996, 11997, 15070, 12003, 10980, 13029, 12007, 14057, 12012, 10990, 12016, 10994, 15096, 11003, 14082, 11013, 13061, 14098, 14100, 13076, 14107, 14108, 14109, 14113, 11042, 11049, 14122, 11057, 11066, 12094, 11076, 14150, 13127, 11097, 16218, 12129, 11109, 13158, 14193, 11122, 12156, 13184, 11140, 11146, 12173, 13198, 14222, 11150, 15249, 12177, 13204, 10135, 10136, 10140, 10141, 12191, 10146, 12197, 10154, 10155, 14252, 10157, 13230, 14254, 14256, 13232, 10158, 12206, 10165, 14262, 11193, 10170, 12217, 13244, 13241, 11203, 15304, 13256, 10185, 13264, 12250, 15323, 13277, 12255, 10208, 14307, 12264, 12265, 12266, 13290, 13296, 14321, 11252, 12278, 13303, 12280, 11259, 15356]

# %%
aiport_dict = {key : airports[airports["Code"] == key]["Description"].values[0].split(":")[-1].strip() for key in third}

# %%
# aiport_dict = {}
# for key in third:
#     print(airports[airports["Code"] == key]["Description"].values[0].split(":")[-1].strip())
#     aiport_dict[key] =
# Out:
# James M Cox/Dayton International
# King Salmon Airport
# Tulsa International
# Ronald Reagan Washington National
# Tucson International
# Albany International
# Cherry Capital
# Denver International
# Joslin Field - Magic Valley Regional
# General Mitchell International
# Muskegon County
# Dallas/Fort Worth International
# Wilmington International
# Rick Husband Amarillo International
# Texarkana Regional-Webb Field
# Dothan Regional
# Ford
# Melbourne International
# Indianapolis International
# McGhee Tyson
# Tyler Pounds Regional
# Quad City International
# Falls International Einarson Field
# Ted Stevens Anchorage International
# Monroe Regional
# Dillingham Airport
# Duluth International
# Mammoth Lakes Airport
# Alpena County Regional
# Sloulin Field International
# Long Island MacArthur
# Ithaca Tompkins Regional
# Mobile Regional
# Hilo International
# Rapid City Regional
# Minot International
# Aspen Pitkin County Sardy Field
# Northeast Florida Regional
# Sawyer International
# Durango La Plata County
# Redding Municipal
# Jackson Hole
# Roberts Field
# Raleigh-Durham International
# Hartsfield-Jackson Atlanta International
# Des Moines International
# Jackson Medgar Wiley Evers International
# Jacksonville International
# Monterey Regional
# Appleton International
# Detroit Metro Wayne County
# Dane County Regional-Truax Field
# Missoula International
# Minneapolis-St Paul International
# Austin - Bergstrom International
# Louis Armstrong New Orleans International
# Devils Lake Regional
# Rhinelander/Oneida County
# Richmond International
# John F. Kennedy International
# Montrose Regional
# Asheville Regional
# Wilkes Barre Scranton International
# Chippewa Valley Regional
# Rock Springs Sweetwater County
# Northwest Florida Beaches International
# Joplin Regional
# Kalamazoo/Battle Creek International
# Martha's Vineyard Airport
# Jamestown Regional
# Ellington
# Reno/Tahoe International
# Juneau International
# Roanoke Blacksburg Regional Woodrum Field
# Eagle County Regional
# Greater Rochester International
# Valdosta Regional
# Roswell International Air Center
# Elko Regional
# Eglin AFB Destin Fort Walton Beach
# Myrtle Beach International
# Elmira/Corning Regional
# El Paso International
# Bradley International
# Rochester International
# Southwest Florida International
# Bethel Airport
# Erie International/Tom Ridge Field
# Meadows Field
# Delta County
# Greater Binghamton/Edwin A. Link Field
# Santa Fe Municipal
# Mahlon Sweet Field
# Bangor International
# San Diego International
# San Antonio International
# Evansville Regional
# Savannah/Hilton Head International
# Santa Barbara Municipal
# Newark Liberty International
# Coastal Carolina Regional
# Birmingham-Shuttlesworth International
# Key West International
# South Bend International
# San Luis County Regional
# Fairbanks International
# Deadhorse Airport
# Fresno Yosemite International
# Hector International
# University Park
# Fayetteville Regional/Grannis Field
# Billings Logan International
# Glacier Park International
# Bismarck Municipal
# Bemidji Regional
# Louisville International-Standiford Field
# Seattle/Tacoma International
# Bellingham International
# Flagstaff Pulliam
# Fort Lauderdale-Hollywood International
# San Francisco International
# Central Illinois Regional
# Springfield-Branson National
# Nashville International
# Bishop International
# St George Regional
# Kona International Airport at Keahole
# Boise Air Terminal
# Shreveport Regional
# Logan International
# Wrangell Airport
# Albert J Ellis
# Metropolitan Oakland International
# Jack Brooks Regional
# Brunswick Golden Isles
# Sitka Rocky Gutierrez
# Rafael Hernandez
# Norman Y. Mineta San Jose International
# Brainerd Lakes Regional
# San Angelo Regional/Mathis Field
# Brownsville South Padre Island International
# Luis Munoz Marin International
# Joe Foss Field
# Wiley Post/Will Rogers Memorial
# Fort Smith Regional
# Kahului Airport
# Ketchikan International
# Salt Lake City International
# Yellowstone
# Will Rogers World
# Bert Mooney
# Baton Rouge Metropolitan/Ryan Field
# Burlington International
# Buffalo Niagara International
# Sacramento International
# Eppley Airfield
# Bob Hope
# Nome Airport
# Northwest Arkansas Regional
# Fort Wayne International
# Santa Maria Public/Capt. G. Allan Hancock Field
# John Wayne Airport-Orange County
# Ontario International
# Baltimore/Washington International Thurgood Marshall
# Capital Region International
# Laramie Regional
# McCarran International
# Gillette Campbell County
# Lawton-Fort Sill Regional
# Los Angeles International
# Garden City Regional
# Lubbock Preston Smith International
# Bozeman Yellowstone International
# Arnold Palmer Regional
# Abraham Lincoln Capital
# Chicago O'Hare International
# Norfolk International
# Spokane International
# Worcester Regional
# Francisco C. Ada Saipan International
# Sheppard AFB/Wichita Falls Municipal
# Lake Charles Regional
# Columbia Metropolitan
# Yakutat Airport
# Akron-Canton Regional
# Grand Forks International
# East Texas Regional
# Sarasota/Bradenton International
# Southwest Oregon Regional
# Blue Grass
# Ralph Wien Memorial
# Grand Junction Regional
# Lafayette Regional Paul Fournet Field
# LaGuardia
# Long Beach Airport
# Cedar City Regional
# St Louis Lambert International
# Merle K Mudhole Smith
# Cyril E King
# Gainesville Regional
# Henry E. Rohlsen
# Lihue Airport
# Barkley Regional
# Bill and Hillary Clinton Nat Adams Field
# Friedman Memorial
# Gulfport-Biloxi International
# Green Bay Austin Straubel International
# Plattsburgh International
# Palm Beach International
# Central Nebraska Regional
# Robert Gray AAF
# Gerald R. Ford International
# Piedmont Triad International
# Greenville-Spartanburg International
# Gustavus Airport
# Stewart International
# Great Falls International
# Lovell Field
# Lincoln Airport
# Golden Triangle Regional
# Portland International
# Gunnison-Crested Butte Regional
# Charlottesville Albemarle
# Guam International
# Charleston AFB/International
# Syracuse Hancock International
# The Eastern Iowa
# Punta Gorda Airport
# Chippewa County International
# Laredo International
# Newport News/Williamsburg International
# Philadelphia International
# La Crosse Regional
# Phoenix Sky Harbor International
# General Downing - Peoria International
# Hattiesburg-Laurel Regional
# Pocatello Regional
# Cleveland-Hopkins International
# Easterwood Field
# Pittsburgh International
# Charlotte Douglas International
# John Glenn Columbus International
# Yampa Valley
# Houghton County Memorial
# Pellston Regional Airport of Emmet County
# Lewiston Nez Perce County
# Yellowstone Regional
# Yuma MCAS/Yuma International
# Range Regional
# City of Colorado Springs Municipal
# Midland International Air and Space Port
# Pensacola International
# Casper/Natrona County International
# Helena Regional
# MBS International
# Corpus Christi International
# Yeager
# Daniel K Inouye International
# Kansas City International
# Pago Pago International
# Columbus Airport
# Tallahassee International
# Lea County Regional
# Orlando International
# Lehigh Valley International
# Abilene Regional
# Albuquerque International Sunport
# Aberdeen Regional
# William P Hobby
# Southwest Georgia Regional
# Westchester County
# Nantucket Memorial
# Waco Regional
# Tri Cities
# California Redwood Coast Humboldt County
# Harrisburg International
# Mercedita
# Petersburg James A Johnson
# Chicago Midway International
# Atlantic City International
# Valley International
# Adak
# Palm Springs International
# Cincinnati/Northern Kentucky International
# Kodiak Airport
# Huntsville International-Carl T Jones Field
# Memphis International
# Key Field
# Central Wisconsin
# Tampa International
# McAllen Miller International
# Alexandria International
# Rogue Valley International - Medford
# Barnstable Municipal-Boardman/Polando Field
# Tri Cities
# Montgomery Regional
# Hays Regional
# Augusta Regional at Bush Field
# Theodore Francis Green State
# Washington Dulles International
# Niagara Falls International
# George Bush Intercontinental/Houston
# Manhattan Regional
# Manchester-Boston Regional
# Portland International Jetport
# Daytona Beach International
# Wichita Dwight D Eisenhower National
# Miami International
# Idaho Falls Regional
# Dallas Love Field
# Trenton Mercer

# %%
print(aiport_dict)
# Out:
# {11267: 'Dayton, OH: James M Cox/Dayton International', 10245: 'King Salmon, AK: King Salmon Airport', 15370: 'Tulsa, OK: Tulsa International', 11278: 'Washington, DC: Ronald Reagan Washington National', 15376: 'Tucson, AZ: Tucson International', 10257: 'Albany, NY: Albany International', 15380: 'Traverse City, MI: Cherry Capital', 11292: 'Denver, CO: Denver International', 15389: 'Twin Falls, ID: Joslin Field - Magic Valley Regional', 13342: 'Milwaukee, WI: General Mitchell International', 13344: 'Muskegon, MI: Muskegon County', 11298: 'Dallas/Fort Worth, TX: Dallas/Fort Worth International', 12323: 'Wilmington, NC: Wilmington International', 10279: 'Amarillo, TX: Rick Husband Amarillo International', 15401: 'Texarkana, AR: Texarkana Regional-Webb Field', 11308: 'Dothan, AL: Dothan Regional', 12335: 'Iron Mountain/Kingsfd, MI: Ford', 13360: 'Melbourne, FL: Melbourne International', 12339: 'Indianapolis, IN: Indianapolis International', 15412: 'Knoxville, TN: McGhee Tyson', 15411: 'Tyler, TX: Tyler Pounds Regional', 13367: 'Moline, IL: Quad City International', 12343: 'International Falls, MN: Falls International Einarson Field', 10299: 'Anchorage, AK: Ted Stevens Anchorage International', 13377: 'Monroe, LA: Monroe Regional', 11336: 'Dillingham, AK: Dillingham Airport', 11337: 'Duluth, MN: Duluth International', 13388: 'Mammoth Lakes, CA: Mammoth Lakes Airport', 10333: 'Alpena, MI: Alpena County Regional', 12389: 'Williston, ND: Sloulin Field International', 12391: 'Islip, NY: Long Island MacArthur', 12397: 'Ithaca/Cortland, NY: Ithaca Tompkins Regional', 13422: 'Mobile, AL: Mobile Regional', 12402: 'Hilo, HI: Hilo International', 14457: 'Rapid City, SD: Rapid City Regional', 13433: 'Minot, ND: Minot International', 10372: 'Aspen, CO: Aspen Pitkin County Sardy Field', 15497: 'St. Augustine, FL: Northeast Florida Regional', 13459: 'Marquette, MI: Sawyer International', 11413: 'Durango, CO: Durango La Plata County', 14487: 'Redding, CA: Redding Municipal', 12441: 'Jackson, WY: Jackson Hole', 14489: 'Bend/Redmond, OR: Roberts Field', 14492: 'Raleigh/Durham, NC: Raleigh-Durham International', 10397: 'Atlanta, GA: Hartsfield-Jackson Atlanta International', 11423: 'Des Moines, IA: Des Moines International', 12448: 'Jackson/Vicksburg, MS: Jackson Medgar Wiley Evers International', 12451: 'Jacksonville, FL: Jacksonville International', 13476: 'Monterey, CA: Monterey Regional', 10408: 'Appleton, WI: Appleton International', 11433: 'Detroit, MI: Detroit Metro Wayne County', 13485: 'Madison, WI: Dane County Regional-Truax Field', 13486: 'Missoula, MT: Missoula International', 13487: 'Minneapolis, MN: Minneapolis-St Paul International', 10423: 'Austin, TX: Austin - Bergstrom International', 13495: 'New Orleans, LA: Louis Armstrong New Orleans International', 11447: 'Devils Lake, ND: Devils Lake Regional', 14520: 'Rhinelander, WI: Rhinelander/Oneida County', 14524: 'Richmond, VA: Richmond International', 12478: 'New York, NY: John F. Kennedy International', 13502: 'Montrose/Delta, CO: Montrose Regional', 10431: 'Asheville, NC: Asheville Regional', 10434: 'Scranton/Wilkes-Barre, PA: Wilkes Barre Scranton International', 11471: 'Eau Claire, WI: Chippewa Valley Regional', 14543: 'Rock Springs, WY: Rock Springs Sweetwater County', 11481: 'Panama City, FL: Northwest Florida Beaches International', 12511: 'Joplin, MO: Joplin Regional', 10469: 'Kalamazoo, MI: Kalamazoo/Battle Creek International', 13541: "Martha's Vineyard, MA: Martha's Vineyard Airport", 12519: 'Jamestown, ND: Jamestown Regional', 11495: 'Houston, TX: Ellington', 14570: 'Reno, NV: Reno/Tahoe International', 12523: 'Juneau, AK: Juneau International', 14574: 'Roanoke, VA: Roanoke Blacksburg Regional Woodrum Field', 11503: 'Eagle, CO: Eagle County Regional', 14576: 'Rochester, NY: Greater Rochester International', 15607: 'Valdosta, GA: Valdosta Regional', 14588: 'Roswell, NM: Roswell International Air Center', 11525: 'Elko, NV: Elko Regional', 15624: 'Valparaiso, FL: Eglin AFB Des ...

# %%
carrier_list
# Out:
# array(['AA', 'AS', 'B6', 'DL', 'F9', 'HA', 'NK', 'EV', 'OO', 'UA', 'VX',
#        'WN'], dtype=object)

# %%
comp_dict = {key : companies[companies["Code"] == key]["Description"].values[0] for key in carrier_list}

# %%
print(comp_dict)
# Out:
# {'AA': 'American Airlines Inc.', 'AS': 'Alaska Airlines Inc.', 'B6': 'JetBlue Airways', 'DL': 'Delta Air Lines Inc.', 'F9': 'Frontier Airlines Inc.', 'HA': 'Hawaiian Airlines Inc.', 'NK': 'Spirit Air Lines', 'EV': 'ExpressJet Airlines Inc.', 'OO': 'SkyWest Airlines Inc.', 'UA': 'United Air Lines Inc.', 'VX': 'Virgin America', 'WN': 'Southwest Airlines Co.'}

# %%
# for key in carrier_list:
#     print(companies[companies["Code"] == key]["Description"].values[0])
# Out:
# American Airlines Inc.
# Alaska Airlines Inc.
# JetBlue Airways
# Delta Air Lines Inc.
# Frontier Airlines Inc.
# Hawaiian Airlines Inc.
# Spirit Air Lines
# ExpressJet Airlines Inc.
# SkyWest Airlines Inc.
# United Air Lines Inc.
# Virgin America
# Southwest Airlines Co.

# %%
import pickle
def save_obj(obj, name ):
    with open('prod/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6261a7fcced7> in <module>()
#       4         pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
#       5
# ----> 6 save_obj(aiport_dict, "airport")
#       7 save_obj(comp_dict, "company")
#
# NameError: name 'aiport_dict' is not defined

# %%
save_obj(aiport_dict, "airport")
save_obj(comp_dict, "company")
save_obj(list(X), "index")
